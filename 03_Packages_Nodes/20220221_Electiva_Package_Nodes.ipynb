# %% [markdown]
# # Electiva Técnica I - Introducción Robot Operating System (ROS1)¶
#
# ## Construcción de Paquetes y Nodos
#
# ### David Rozo Osorio, I.M, M.Sc.

# %% [markdown]
# ## Breve introducción a Python
#
# - Objetivo: realizar una nivelación acerca de los elementos más generales de la programación en Python.
#
# - Procedimiento:
#  1. Interfaz de Usuario VSCode.
#  2. Hola mundo!
#  3. Funciones.
#  4. Operaciones matemáticas.
#  5. Condicionales.
#  6. Ciclos.

# %% [markdown]
# ### Estructura básica
#
# - Imprimir en pantalla
# ```python
# print("hola mundo!")
# ```
# - Variables:
#   - Los identificadores son nombres de variables, funciones y módulos usados en un programa.
#   - Todo identificador debe comenzar con una letra (a-z) o guión bajo, seguido por una secuencia de letras, digitos o palabras unidas por guiones.
#   - Case sensitive.
#   - Variables construidas en minúsculas sepradas por guión bajo (ejm: contador_caracteres).
#   - Dado que los espacios son irrelevantes en las expresiones, se recomiendan escribir de forma explicita la información.
#
# - Obtener información de la terminal
# ```python
# num_str = input("ingrese un número entre 0 y 9: ")
# print(num_str)
# print(float(num_str))
# ```
#
# - Asignación
# ```python
# a, b, c = 1, 2, 3
# print(a,b,c)
# c, d = a+b, a-b
# print(c,d)
# a = 1
# b = 2
# print(a,b)
# b, a = a, b
# print(a,b)
# ```
#
# - Funciones
# ```python
# def hola():
#     print("Hola")
#     print("Mundo")
# hola()
# def hola(Nombre,Apellido):
#     print("Hola, ")
#     print(Nombre, Apellido)
# hola("John","Doe")
# def c2f(c):
#     f=(9/5) * c + 32
#     return f
# resultado=c2f(22)
# ```
#
# - Operaciones matemáticas
# ```python
# print(5/3) # división
# print(5//3) # operación "floor"
# print(5%3) # operador "modulus"
# print(2.0**3) # potencia 2^3
# print(5*2**3) # equivalente 5*(2^3)
# print(abs(-5)) # valor abs
# ```
#
# - Librería Math
# ```python
# import math
# print(math.pi)
# print(math.inf) # cantidad equivalente a infinito
# print(math.nan) # cantidad no-number
# print(math.exp(4)) # e^4
# print(math.sqrt(9)) #raíz cuadrada
# print(math.pow(2,3)) # 2^3
# print(math.ceil(4.3)) # redondeo por exceso
# print(math.floor(4.6)) # redondeo es defecto
# print(math.factorial(3)) # 3!
# print(math.sin(math.pi/2)) # argumento en radianes
# print(math.asin(1)) # arcsin
# print(math.degrees(math.pi/2)) # radianes -> grados
# print(math.radians(90)) # grados -> radianes
# ```
#
# - Condicionales
#   - `if` sintax
# ```python
# if condition:
#     statement_block
# ```
#   - **Ejm**
# ```python
# def fn_conv_peso():
#     lb = float(input('Cuál es el peso del objeto: '))
#     kg = 0.453592 * lb
#     print('El peso del objeto es: ',format(kg,'.2f'), 'kg')
#
#     if kg > 20:
#         print('El objeto supera el peso permitido por la aerolinea')
#     if kg < 20:
#         print('El objeto se encuentra dentro de limite permitido')
# fn_conv_peso()
# ```
#   - `if-else` sintax
# ```python
# if condition:
#     statement_block_1
# else:
#     statement_block_2
# ```
#   - **Ejm**
# ```python
# def fn_conv_peso_v2():
#     lb = float(input('Cuál es el peso del objeto: '))
#     kg = 0.453592 * lb
#     print('El peso del objeto es: ',format(kg,'.2f'), 'kg')
#
#     if kg > 20:
#         print('El objeto supera el peso permitido por la aerolinea')
#     else:
#         print('El objeto se encuentra dentro de limite permitido')
# fn_conv_peso()
# ```
#   - `if-elif-else` sintax
# ```python
# if condition 1:
#     statement_block_1
# elif condition 2:
#     statement_block_2
# elif condition 3:
#     statement_block_3
# ...
# else:
#     statement_block_n
# ```
#
# - Ciclos
#   - `For` sintax
# ```python
# for index in sequence:
#     statement_block
# ```
#   - **Ejm**
# ```python
# import math
# for x in range(0,3):
#     print('x =',x,',','sin(x)=',format(math.sin(x),'.4f'))
#     print()
# ```
#   - `While` sintax
# ```python
# while condition:
#     Statement_block
# ```
#   - **Ejm**
# ```python
# i=0
# while i < 5:
#     print(i)
#     i+=1
# ```

# %% [markdown]
# ## Introducción a la implementación de Nodos
#
# - Objetivo: diseñar e implementar un *node* que envíe mensajes al simulador Turtlesim
#
#
# - Procedimiento:
#  1. Creación de paquetes.
#  2. Creación de un nodo mínimo.
#  3. Implementación del nodo particular.
#  4. Definición del publicador.
#  5. Definición del subscriptor.
#  6. Compilación del paquete.
#  7. Ejecución.

# %% [markdown]
# ### Creación del Espacio de Trabajo (*workspace*) un paquete (*pkg*)
#
# 1. Ubicado en `Home/User` crear la carpeta asociada para el *Workspace*
# ```bash
# ~$ mkdir -p <worksspace_name>/src
# ```
#  **Ej.** La carpeta se llama `catkin_ws` y esta ubicada en `Home/User`:
# ```bash
# ~$ mkdir -p ~/catkin_ws/src
# ```
#
# 2. Inicializando el *Workspace* desde la carpeta `/src`:
# ```bash
# ~/catkin_ws/src $ catkin_init_workspace
# ```
#
# 3. Ubicado en la raíz del espacio de trabajo `catkin_ws`:
# ```bash
# ~/catkin_ws $ catkin_make
# ```
#
# 4. Agregar el espacio de trabajo al archivo `.bashrc`:
# ```bash
# $ echo "source ~/catkin_ws/devel/setup.bash" >> ~/.bashrc
# $ source ~/.bashrc
# ```
#
# 5. Creación del paquete, dentro de la carperta `src` (`catkin_ws/src`):
# ```bash
# ~/catkin_ws/src $ catkin_create_pkg <pkg_name> <pkg_deps>
# ```
#  **Nota**: el `<pkg_name>` por convención todo en minúsculas y si es necesario separado por guion bajo.
#
#  **Ej.** el paquete se llamará `hello_world`, con dependencias de: C++, Python y mensajes estándar de ROS:
# ```bash
# ~/catkin_ws/src $ catkin_create_pkg hello_world roscpp rospy std_msgs
# ```
#
#  **Ej.** el paquete se llamará `turtle_pkg_gYY`, con dependencias de: C++, Python y mensajes estándar de ROS:
# ```bash
# ~/catkin_ws/src $ catkin_create_pkg turtle_pkg_gYY roscpp rospy std_msgs
# ```
#
#  **Nota**: el `YY` debe coincidir con la desiganación de Grupo.
#
#
# 6. Iniciar sesión de Visual Studio Code desde la carpeta `catkin_ws`:
#
# ```bash
# ~/catkin_ws $ code .
# ```

# %% [markdown]
# ### Plantilla de nodos (Python)
#
# - Crear una carpeta llamada `template` en `/src` y crea un archivo llamado `temp_node.py`
#
# ```python
# #!/usr/bin/env python
# import rospy
# from std_msgs.msg import String
#
# def node_function():
#     rospy.init_node('NODE_NAME', anonymous=True) #NODE_NAME must change
#
#     rate = rospy.Rate(10) # 10hz
#     while not rospy.is_shutdown():
#         # space left for contruction
#         rate.sleep()
#
# if __name__ == '__main__':
#     try:
#         node_function() #node_function must change
#     except rospy.ROSInterruptException:
#         pass
# ```
#
# - Modificar las propiedades del archivo a ejecutable,
# ```bash
# .../<file_folder_path> $ sudo chmod +x <node_file_name>
# ```

# %% [markdown]
# ### Modificación del nodo plantilla
#
# - Copiar el nodo plantilla a una carpeta llamada `scripts` en el paquete. Renombrar el archivo como `turtle_node_gYY` donde `YY` debe ser modificado con base en el número de grupo asignado.
# - Modificar la plantilla para ajustarla al objetivo de la práctica:
#
# ```python
# #!/usr/bin/env python
# import rospy
# from std_msgs.msg import String
#
# def turtle_node_gYY(): #YY must change
#     rospy.init_node('turtle_node_gYY', anonymous=True) #YY must change
#
#     rate = rospy.Rate(10) # 10hz
#     while not rospy.is_shutdown():
#         # space left for contruction
#         rate.sleep()
#
# if __name__ == '__main__':
#     try:
#         turtle_node_gYY() #YY must change
#     except rospy.ROSInterruptException:
#         pass
# ```

# %% [markdown]
# ### Definición del Publicador
#
# - Inclusión de librerías en el programa.
#
# ```python
# from geometry_msgs.msg import Twist
# ```
#
# - En la parte incial de la función del *node*, crear el publicador.
#
# ```python
# # publisher obj (topic_name,msg_type,queue==buffer)
# cmdvel_pub = rospy.Publisher('/turtle1/cmd_vel',Twist,queue_size=10)
# # def twist variable
# cmd_vel = Twist()
# ```
#
# - Modificar la estructura del `While` para que contruya y envíe el mensaje.
#
# ```python
# while not rospy.is_shutdown():
#     #...
#     cmd_vel.linear.x = 0.5  #float(sys.argv[1])#
#     cmd_vel.angular.z = 1.0 #float(sys.argv[2])#
#     cmdvel_pub.publish(cmd_vel)
#     #...
# ```

# %% [markdown]
# - Modificación del archivo `CMakeList.txt` del paquete:
#
# ```TypeScript
# ...
# catkin_install_python(PROGRAMS scripts/<node_name_file>.py
#   DESTINATION ${CATKIN_PACKAGE_BIN_DESTINATION}
# )
# ...
# ```
#
# - Compilar el paquete, desde la raíz del espacio de trabajo `catkin_ws`:
#
# ```bash
# ~/catkin_ws $ catkin_make
# ```
#
# - Agregar en el archivo `.bashrc` la dirección de la carpeta de compilación.
#
# ```shell
# ~$ nano ~/.bashrc
# -> source ~/catkin_ws/devel/setup.bash
# $ source ~/.bashrc
# ```

# %% [markdown]
# ### Verificación de aplicación:
#
# 1. Terminal No. 1 Inicializar el ROS-Master
#
# ```bash
# $ roscore
# ```
#
# 2. Terminal No. 2. Iniciar el simulador `Turtlesim`.
#
# ```bash
# $ rosrun turtlesim turtlesim_node
# ```
#
# 3. Terminal No. 3. Iniciar el nodo `turtle_node_gYY`
#
# ```bash
# $ rosrun turtle_pkg_gYY turtle_node_gYY
# ```

# %% [markdown]
# ### Definición del Subscriptor
#
# - Inclusión de librerías en el programa
#
# ```python
# from turtlesim.msg import Pose
# # system library
# import sys
# ```
#
# - En la parte incial de la función del *node*, crear el subscriptor:
#
# ```python
# # create a topic subscriber
# # obj (topic_name,msg_type, callback_handler, buffer)
# pose_subs = rospy.Subscriber('/turtle1/pose',Pose,pose_callback)
# ```
#
# - Creación de una función (*method*) encargada de leer el mensaje (`pose_callback`).
#
# ```python
# def pose_callback(data):
#     msg = 'X: {:.3f}, Y: {:.3f}, Theta: {:.3f}'.format(data.x,data.y,data.theta)
#     rospy.loginfo(msg)
# ```
#
# - Guardar y compilar nuevamente el *pkg*
# ```bash
# ~/catkin_ws $ catkin_make
# ```

# %% [markdown]
# ### Verificación de aplicación:
#
# 1. Terminal No. 1. Iniciar el simulador `Turtlesim`.
#
# ```bash
# $ rosrun turtlesim turtlesim_node
# ```
#
# 2. Terminal No. 2. Iniciar el nodo `turtle_node_gYY`
#
# ```bash
# $ rosrun turtle_pkg_gYY turtle_node_gYY
# ```
